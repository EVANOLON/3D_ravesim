# %%
# !pwd
# Out:
# /mnt/d/rave-sim-main/rave-sim-main/notebooks/test_notebooks

# %%
# !cd /mnt/d/rave-sim-main/rave-sim-main/fast-wave/build-Release && cuda-memcheck ./fastwave /mnt/d/rave-sim-main/rave-sim-main/notebooks/test_notebooks/capsule3d.ipynb
# Out:
# ========= CUDA-MEMCHECK
# ========= This tool is deprecated and will be removed in a future release of the CUDA toolkit
# ========= Please use the compute-sanitizer tool as a drop-in replacement
# Source index is required
#
# Usage:
#   fastwave [options] [argument]
# Available options:
#   -s, --source_idx  The index of the source point to simulate (required)
#       --history_dz  Z-Spacing for history entries (optional)
#   -h, --help        print this help screen
#
# ========= ERROR SUMMARY: 0 errors
